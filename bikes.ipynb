# %%
import pandas as pd
import seaborn as sns
import numpy as np
# might not be necessary in notebook because it's already handled
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/hour.csv')

# %%
# 100 first records
df.head(100)
# Out:
#     instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday
# 0         1  2011-01-01       1   0     1   0        0        6           0  \
# 1         2  2011-01-01       1   0     1   1        0        6           0
# 2         3  2011-01-01       1   0     1   2        0        6           0
# 3         4  2011-01-01       1   0     1   3        0        6           0
# 4         5  2011-01-01       1   0     1   4        0        6           0
# ..      ...         ...     ...  ..   ...  ..      ...      ...         ...
# 95       96  2011-01-05       1   0     1   4        0        3           1
# 96       97  2011-01-05       1   0     1   5        0        3           1
# 97       98  2011-01-05       1   0     1   6        0        3           1
# 98       99  2011-01-05       1   0     1   7        0        3           1
# 99      100  2011-01-05       1   0     1   8        0        3           1
#
# ...

# %%
# 10 last records
df.tail(10)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday
# 17369    17370  2012-12-31       1   1    12  14        0        1  \
# 17370    17371  2012-12-31       1   1    12  15        0        1
# 17371    17372  2012-12-31       1   1    12  16        0        1
# 17372    17373  2012-12-31       1   1    12  17        0        1
# 17373    17374  2012-12-31       1   1    12  18        0        1
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual
# 17369           1           2  0.28  0.2727  0.45     0.2239      62  \
# 17370           1           2  0.28  0.2879  0.45     0.1343      69
# ...

# %%
# 10 random records
df.sample(10)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday
# 8814      8815  2012-01-08       1   1     1   2        0        0  \
# 6791      6792  2011-10-15       4   0    10  13        0        6
# 545        546  2011-01-24       1   0     1  21        0        1
# 14548    14549  2012-09-03       3   1     9   9        1        1
# 14131    14132  2012-08-17       3   1     8   0        0        5
# 2821      2822  2011-05-02       2   0     5  11        0        1
# 4082      4083  2011-06-24       3   0     6   0        0        5
# 14078    14079  2012-08-14       3   1     8  19        0        2
# 8606      8607  2011-12-30       1   0    12   9        0        5
# 16719    16720  2012-12-04       4   1    12  10        0        2
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual
# 8814            0           1  0.36  0.3333  0.37     0.2836      10  \
# 6791            0           1  0.60  0.6212  0.35     0.4627     171
# ...

# %%
# descripctive statistics of dataframe
df.describe()
# Out:
#           instant        season            yr          mnth            hr
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000  \
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000  \
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
# variant of rented bikes number related to the hour of the day
sns.barplot(
    # whole dataframe
    data=df,
    # feature of dataframe on X axis (hour of the day)
    x='hr',
    # feature of dataframe on Y axis (count of bikes)
    y='cnt'
)
# Out:
# <Axes: xlabel='hr', ylabel='cnt'>

# %%
# features of dataframe
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# count of render bikes related to many features
for i in ['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']:
    sns.barplot(data=df, x=i, y='cnt')
    # because it would print all graphs one above the other
    plt.show()

# %%
for i in ['temp', 'atemp', 'hum', 'windspeed']:
    sns.scatterplot(data=df, x=i, y='cnt')
    plt.show()

# %%
sns.jointplot(
    data=df,
    x='temp',
    y='cnt',
    # kernel density extimation => ex. geographical chart
    kind='kde'
)

# %%
# cross features graphs, how features are related
sns.pairplot(
    data=df[ ['temp', 'hum', 'windspeed', 'cnt'] ]
)

# %%
# combine workingdays to the hour with different colors
sns.barplot(
    data=df,
    x='hr',
    y='cnt',
    hue='workingday'
)
# Out:
# <Axes: xlabel='hr', ylabel='cnt'>

# %%
sns.relplot(
    data=df,
    x='hr',
    y='cnt',
    # display seasons with different colors
    hue='season',
    # 2 graphs columns with working day 0 and working day 1
    col='workingday',
    # default is scatterplot
    kind='line',
    # scale sizes basing on count
    size='cnt'
)

# %%
sns.relplot(
    data=df,
    x='temp',
    y='hum',
    hue='workingday',
    col='yr',
    row='weathersit'
)

# %%
sns.boxplot(
    data=df,
    x='season',
    y='cnt',
    hue='holiday'
)
# Out:
# <Axes: xlabel='season', ylabel='cnt'>

# %%
sns.violinplot(
    data=df,
    x='season',
    y='cnt',
    hue='holiday'
)
# Out:
# <Axes: xlabel='season', ylabel='cnt'>
